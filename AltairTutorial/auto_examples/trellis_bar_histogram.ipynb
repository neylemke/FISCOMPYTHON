# %% [markdown]
# <small>*Notebook auto-generated from [``altair/examples/json/trellis_bar_histogram.vl.json``](../../altair/examples/json/trellis_bar_histogram.vl.json)*</small>
#
# # Altair Example: Trellis Bar Histogram
#
# --

# %% [markdown]
# ## Load Dataset
# The data comes in the form of a Pandas Dataframe:

# %%
from altair import load_dataset
data = load_dataset("cars")
data.head()
# Out:
#    Acceleration  Cylinders  Displacement  Horsepower  Miles_per_Gallon  \
# 0          12.0          8           307         130                18
# 1          11.5          8           350         165                15
# 2          11.0          8           318         150                18
# 3          12.0          8           304         150                16
# 4          10.5          8           302         140                17
#
#                         Name Origin  Weight_in_lbs        Year
# 0  chevrolet chevelle malibu    USA           3504  1970-01-01
# 1          buick skylark 320    USA           3693  1970-01-01
# 2         plymouth satellite    USA           3436  1970-01-01
# 3              amc rebel sst    USA           3433  1970-01-01
# 4                ford torino    USA           3449  1970-01-01

# %% [markdown]
# ## Define Altair Specification

# %%
from altair import *  # Import the altair API

chart = Chart(data).mark_bar().encode(
    row='Origin:N',
    x=X('Horsepower:Q',
        bin=Bin(
            maxbins=15.0,
        ),
    ),
    y='count(*):Q',
)

# %% [markdown]
# IPython rich display will invoke Vega-Lite:

# %%
chart
# Out:
# <div class="vega-embed" id="6c56fb42-72fe-4fb3-99f6-5ad1d4f8064a"></div>
#
# <style>
# .vega-embed svg, .vega-embed canvas {
#   border: 1px dotted gray;
# }
#
# .vega-embed .vega-actions a {
#   margin-right: 6px;
# }
# </style>

# %% [markdown]
# ## Output Vega-Lite Specification

# %% [markdown]
# Generate JSON dict, leaving data out:

# %%
chart.to_dict(data=False)
# Out:
# {'encoding': {'row': {'field': 'Origin', 'type': 'nominal'},
#   'x': {'bin': {'maxbins': 15.0},
#    'field': 'Horsepower',
#    'type': 'quantitative'},
#   'y': {'aggregate': 'count', 'field': '*', 'type': 'quantitative'}},
#  'mark': 'bar'}
