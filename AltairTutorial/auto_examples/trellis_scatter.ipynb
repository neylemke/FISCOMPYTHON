# %% [markdown]
# <small>*Notebook auto-generated from [``altair/examples/json/trellis_scatter.vl.json``](../../altair/examples/json/trellis_scatter.vl.json)*</small>
#
# # Altair Example: Trellis Scatter
#
# --

# %% [markdown]
# ## Load Dataset
# The data comes in the form of a Pandas Dataframe:

# %%
from altair import load_dataset
data = load_dataset("movies")
data.head()
# Out:
#           Creative_Type Director Distributor  IMDB_Rating  IMDB_Votes  \
# 0                  None     None    Gramercy          6.1        1071
# 1                  None     None      Strand          6.9         207
# 2                  None     None   Lionsgate          6.8         865
# 3                  None     None   Fine Line          NaN         NaN
# 4  Contemporary Fiction     None     Trimark          3.4         165
#
#   MPAA_Rating Major_Genre  Production_Budget Release_Date  \
# 0           R        None            8000000    12-Jun-98
# 1           R       Drama             300000     7-Aug-98
# 2        None      Comedy             250000    28-Aug-98
# 3        None      Comedy             300000    11-Sep-98
# 4           R       Drama            1000000     9-Oct-98
#
#    Rotten_Tomatoes_Rating  Running_Time_min               Source  \
# 0                     NaN               NaN                 None
# 1                     NaN               NaN                 None
# 2                     NaN               NaN                 None
# 3                      13               NaN                 None
# 4                      62               NaN  Original Screenplay
#
#                         Title  US_DVD_Sales  US_Gross  Worldwide_Gross
# 0              The Land Girls           NaN    146083           146083
# 1      First Love, Last Rites           NaN     10876            10876
# 2  I Married a Strange Person           NaN    203134           203134
# 3        Let's Talk About Sex           NaN    373615           373615
# 4                        Slam           NaN   1009819          1087521

# %% [markdown]
# ## Define Altair Specification

# %%
from altair import *  # Import the altair API

chart = Chart(data).mark_point().encode(
    column='MPAA_Rating:O',
    x='Worldwide_Gross:Q',
    y='US_DVD_Sales:Q',
)

# %% [markdown]
# IPython rich display will invoke Vega-Lite:

# %%
chart
# Out:
# <div class="vega-embed" id="f9c06436-000b-41d1-83af-53e46fece6a7"></div>
#
# <style>
# .vega-embed svg, .vega-embed canvas {
#   border: 1px dotted gray;
# }
#
# .vega-embed .vega-actions a {
#   margin-right: 6px;
# }
# </style>

# %% [markdown]
# ## Output Vega-Lite Specification

# %% [markdown]
# Generate JSON dict, leaving data out:

# %%
chart.to_dict(data=False)
# Out:
# {'encoding': {'column': {'field': 'MPAA_Rating', 'type': 'ordinal'},
#   'x': {'field': 'Worldwide_Gross', 'type': 'quantitative'},
#   'y': {'field': 'US_DVD_Sales', 'type': 'quantitative'}},
#  'mark': 'point'}
