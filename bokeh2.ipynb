# %%
import numpy as np
from bokeh.plotting import figure, show, gridplot
#from bokeh import layouts
from bokeh.io import output_notebook
import bokeh.models as bm

# %%
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="fc050629-a1f7-4eea-8415-f157a87e1667">Loading BokehJS ...</span>
#     </div>

# %%
from bokeh.plotting import figure, output_file, show

# prepare some data
x = [0.1, 0.5, 1.0, 1.5, 2.0, 2.5, 3.0]
y0 = [i**2 for i in x]
y1 = [10**i for i in x]
y2 = [10**(i**2) for i in x]

# output to static HTML file
output_file("log_lines.html")

# create a new plot
p = figure(
   tools="pan,box_zoom,reset,save",
   y_axis_type="log", y_range=[0.001, 10**11], title="log axis example",
   x_axis_label='sections', y_axis_label='particles'
)

# add some renderers
p.line(x, x, legend="y=x")
p.circle(x, x, legend="y=x", fill_color="white", size=8)
p.line(x, y0, legend="y=x^2", line_width=3)
p.line(x, y1, legend="y=10^x", line_color="red")
p.circle(x, y1, legend="y=10^x", fill_color="red", line_color="red", size=6)
p.line(x, y2, legend="y=10^x^2", line_color="orange", line_dash="4 4")

# show the results
show(p)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="82d8e769-24c4-4468-b6f2-803398ccb49d"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#82d8e769-24c4-4468-b6f2-803398ccb49d").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("82d8e769-24c4-4468-b6f2-803398ccb49d");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '82d8e769-24c4-4468-b6f2-803398ccb49d' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"4c0cb815-31e0-4369-a8b8-2c8aac242521":{"roots":{"references":[{"attributes":{"num_minor_ticks":10},"id":"43e3c85c-bf10-4a37-a66e-565fa8df7103","type":"LogTicker"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[0.1,0.5,1.0,1.5,2.0,2.5,3.0],"y":[1.2589254117941673,3.1622776601683795,10.0,31.622776601683793,100.0,316.22776601683796,1000.0]}},"id":"7c24d628-be0e-4e89-a7f8-5b8943354084","type":"ColumnDataSource"},{"attributes":{"line_color":{"value":"orange"},"line_dash":[4,4],"x":{"field":"x"},"y":{"field":"y"}},"id":"f537676b-f6b8-42b5-9e5e-646080dce9ac","type":"Line"},{"attributes":{"label":{"value":"y=10^x^2"},"renderers":[{"id":"a52cdf86-8703-4864-9948-eb03ded19be9","type":"GlyphRenderer"}]},"id":"9de8c31f-bf92-42b8-ab03-21f67973e0f0","type":"LegendItem"},{"attributes":{"data_source":{"id":"131b5b8d-65dd-497d-8c19-81e4731146af","type":"ColumnDataSource"},"glyph":{"id":"f537676b-f6b8-42b5-9e5e-646080dce9ac","type":"Line"},"hover_glyph":null,"nonselection_glyph":{"id":"1112fdc8-046b-4a68-bc2c-c41b3784ede3","type":"Line"},"selection_glyph":null},"id":"a52cdf86-8703-4864-9948-eb03ded19be9","type":"GlyphRenderer"},{"attributes":{"ticker":null},"id":"1fcc3689-d270-4530-a257-3636a07e5796","type":"LogTickFormatter"},{"attributes":{"axis_label":"particles","formatter":{"id":"1fcc3689-d270-4530-a257-3636a07e5796","type":"LogTickFormatter"},"plot":{"id":"e5e81847-331a-411f-a4ab-a7d1ca07a0ef","subtype":"Figure","type":"Plot"},"ticker":{"id":"43e3c85c-bf10-4a37-a66e-565fa8df7103","type":"LogTicker"}},"id":"2dda8c3b-6ccb-468f-825d-8343bc723acd","type":"LogAxis"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"e115fe3d-06c3-4784-a87b-8c743c7a59db","type":"PanTool"},{"id":"71833388-ae5d-49f0-a23b-7942795fcebc","type":"BoxZoomTool"},{"id":"3e77f2ad-f8b9-4138-b97d-9abae304223d","type":"ResetTool"},{"id":"2f77d894-c01b-4fda-89b9-4e3517f0bde2","type":"SaveTool"}]},"id":"b91471cb-7784-4303-a1f5-04b3b3394b08","type":"Toolbar"},{"attributes":{"data_source":{"id":"5277036d-7c5a-413b-923b-8efcc2ecbfb5","type":"ColumnDataSource"},"glyph":{"id":"46f9b6e3-9054-455e-a683-a013ecace8df","type":"Line"},"hover_glyph":null,"nonselection_glyph":{"id":"7075a87a-41e7-433a-ad7f-2a628474050b","type":"Line"},"selection_glyph":null},"id":"aecbbed5-d8bf-4f9c-89ea-510403d63ec7","type":"GlyphRenderer"},{"attributes":{"fill_color":{"value":"white"},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":8},"x":{"field":"x"},"y":{"field":"y"}},"id":"adf2fa1a-d54e-4549-a89e-8b161c168a3c","type":"Circle"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_dash":[4,4],"x":{"field":"x"},"y":{"field":"y"}},"id":"1112fdc8-046b-4a68-bc2c-c41b3784ede3","type":"Line"},{"attributes":{},"id":"937caa5c-95df-4457-b9d2-15673e171009","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"e5e81847-331a-411f-a4ab-a7d1ca07a0ef","subtype":"Figure","type":"Plot"},"ticker":{"id":"c4b509a3-f128-481b-96af-4a3db8b5a1b0","type":"BasicTicker"}},"id":"7741670d-fd26-40f6-8356-0ffcfd852c82","type":"Grid"},{"attributes":{"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"46f9b6e3-9054-455e-a683-a013ecace8df","type":"Line"},{"attributes":{"callback":null},"id":"60a4a5a8-9d73-438c-b7fa-b18081c22509","type":"DataRange1d"},{"attributes":{"plot":{"id":"e5e81847-331a-411f-a4ab-a7d1ca07a0ef","subtype":"Figure","type":"Plot"}},"id":"3e77f2ad-f8b9-4138-b97d-9abae304223d","type":"ResetTool"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":[0.1,0.5,1.0,1.5,2.0,2.5,3.0],"y":[0.1,0.5,1.0,1.5,2.0,2.5,3.0]}},"id":"5277036d-7c5a-413b-923b-8efcc2ecbfb5","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":[0.1,0.5,1.0,1.5,2.0,2.5,3.0],"y":[1.023292992280754,1.7782794100389228,10.0,177.82794100389228,10000.0,1778279.410038923,1000000000.0]}},"id":"131b5b8d-65dd-497d-8c19-81e4731146af","type":"C ...

# %%
from bokeh.io import output_file, show
from bokeh.layouts import column
from bokeh.plotting import figure

output_file("layout.html")

x = list(range(11))
y0 = x
y1 = [10 - i for i in x]
y2 = [abs(i - 5) for i in x]

# create a new plot
s1 = figure(width=250, plot_height=250, title=None)
s1.circle(x, y0, size=10, color="navy", alpha=0.5)

# create another one
s2 = figure(width=250, height=250, title=None)
s2.triangle(x, y1, size=10, color="firebrick", alpha=0.5)

# create and another
s3 = figure(width=250, height=250, title=None)
s3.square(x, y2, size=10, color="olive", alpha=0.5)

# put the results in a column and show
p = gridplot([[s1, s2,s3]])
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-10-5804340beb21> in <module>()
#       1 from bokeh.io import output_file, show
# ----> 2 from bokeh.layouts import column
#       3 from bokeh.plotting import figure
#       4
#       5 output_file("layout.html")
#
# /Users/neylemke/anaconda/lib/python3.5/site-packages/bokeh/layouts.py in <module>()
#       8 from __future__ import absolute_import
#       9
# ---> 10 from .core.enums import Location, SizingMode
#      11 from .models.tools import ToolbarBox
#      12 from .models.plots import Plot
#
# ImportError: cannot import name 'SizingMode'

# %%
import bokeh.layouts
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-8-105a0b55e332> in <module>()
# ----> 1 import bokeh.layouts
#
# /Users/neylemke/anaconda/lib/python3.5/site-packages/bokeh/layouts.py in <module>()
#       8 from __future__ import absolute_import
#       9
# ---> 10 from .core.enums import Location, SizingMode
#      11 from .models.tools import ToolbarBox
#      12 from .models.plots import Plot
#
# ImportError: cannot import name 'SizingMode'
